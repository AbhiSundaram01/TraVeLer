# %% [markdown]
# # Path Classification via Neural $1$-forms

# %% [markdown]
# In this notebook we give a small example of $1$-form neural networks applied to simple path classification task.

# %%
import numpy as np
import matplotlib as mpl
import torch
import torch.nn as nn
from matplotlib import pyplot as plt
from matplotlib import colors as mcolors

from neural_k_forms.chains import generate_integration_matrix
from neural_k_forms.plotting import plot_component_vector_field

# %% [markdown]
# ### Synthetic Path Generation

# %% [markdown]
# We first need a few functions for doing efficient path integration in this setting.

# %%
def generate_diagonal_paths(num_paths=100,eps = 0.02, num_pts = 50):
    
    Paths = []
    for i in range(num_paths): 
        x = np.sort(np.random.uniform(low=-1, high=1, size=num_pts))
        noise_x = np.random.uniform(low= -eps, high = eps,  size = num_pts)
        noise_y = np.random.uniform(low= -eps, high = eps,  size = num_pts)

        x_trans = np.random.randint(-2,2)
        y_trans = np.random.randint(-2,2)

        r = np.random.uniform(0.2, 2.5)

        x_values = list(r*x+noise_x+x_trans)
        y_values = list(r*np.sin(x+noise_y)+ y_trans)

        path = np.stack((x_values,y_values))
    
        Paths.append(path.T)
        
    return Paths


def generate_antidiagonal_paths(num_paths=100,eps = 0.01, num_pts = 50):
    
    Paths = []
    for i in range(num_paths): 
        x = np.sort(np.random.uniform(low=-1, high=1, size=num_pts))

        noise_x= np.random.uniform(low= -eps, high = eps,  size = num_pts)
        noise_y= np.random.uniform(low= -eps, high = eps,  size = num_pts)

        x_trans = np.random.randint(-2,2)
        y_trans = np.random.randint(-2,2)

        r = np.random.uniform(0.2, 2.5)

        x_values = list(r*x+noise_x + x_trans)
        y_values = list(-r*np.sin(x+noise_y)+y_trans)
        path = np.stack((x_values,y_values))
    
        Paths.append(path.T)
        
    return Paths
        

def generate_circular_paths(num_paths=100,eps = 0.02, num_pts = 50):
    
    Paths = []
    for i in range(num_paths): 
        endpoint = np.random.randint(0,num_pts)

        k = np.random.randint(1,4)
        phase = np.random.uniform(0,2*np.pi)
        
        sample_angles = list(np.sort(np.random.uniform(0,2*np.pi/k, num_pts)+phase))

        #angles= sample_angles[endpoint:]+ sample_angles[:endpoint]
        angles = np.array(sample_angles)
        
        noise_x= np.random.uniform(low= -eps, high = eps,  size = num_pts)
        noise_y= np.random.uniform(low= -eps, high = eps,  size = num_pts)

        x_trans = np.random.randint(-5,5)
        y_trans = np.random.randint(-5,5)

        r = np.random.uniform(0.2, 2.5)

        x_values = r*np.cos(angles)+noise_x
        y_values = r*np.sin(angles)+noise_y

        path = np.stack((x_values,y_values))
    
        Paths.append(path.T)

    return Paths

# %%
# generate data
noise = 0.05
pts = 50

p0 = generate_diagonal_paths(num_paths=100,eps = noise, num_pts = pts)
p1 = generate_antidiagonal_paths(num_paths=100,eps = noise, num_pts = pts)
p2 = generate_circular_paths(num_paths=100,eps = noise, num_pts = pts)

# join together p0, p1, p2
paths = p0#+p1+p2

# %%
paths[0].shape
# Out:
# (50, 2)

# %%
# generate labels
labels = np.concatenate((np.zeros(100),np.ones(100),2*np.ones(100)))

# perform a one hot encoding of the labels and transform to torch
labels = torch.nn.functional.one_hot(torch.tensor(labels).to(torch.int64))

# %%
# turn the above into a function, which takes in a path and ax and plots the path on the ax
def plot_path(path,ax, head_width=0.1, head_length=0.1, alpha = 0.5, color = 'blue', linewidth = 0.5):

    ax.plot(path[:,0],path[:,1], alpha = alpha, color = color, linewidth = linewidth)

    ax.arrow(path[-2,0],path[-2,1],(path[-1,0]-path[-2,0])/3,(path[-1,1]-path[-2,1])/3,head_width = head_width, head_length=head_length, alpha = alpha, color = color)
    
    return ax

# %%
fig, ax = plt.subplots(1,1,figsize = (10,10))

plot_path(paths[0], ax, color = 'green', alpha = 0.6, linewidth = 3)

plot_path(paths[1], ax, color = 'red', alpha = 0.6, linewidth = 3)

plot_path(paths[2], ax, color = 'blue', alpha = 0.6, linewidth = 3)


# save figure
# plt.savefig('figures/synthetic-paths/training_paths.png')

plt.show()

# %%
# a function for calculating the length of a path
def path_length(path):
    """
    Calculates the length of a path
    """
    length = 0
    for i in range(len(path)-1):
        length += np.linalg.norm(path[i+1]-path[i])
    return length

# %% [markdown]
# ### Neural $k$-form Classification Model

# %% [markdown]
# First up, we initialise the vector field as a simple MLP with ReLU activations.

# %%
c = 3 # number of features/columns in cochain data matrix

# intialise 3 neural vector field/1-forms with 2 hidden layers
vf = nn.Sequential(
    nn.Linear(2, 50),
    nn.ReLU(),
    nn.Linear(50, 30),
    nn.ReLU(),
    nn.Linear(30, 2*c)
)

# %% [markdown]
# We can plot the corresponding vector fields below. Note that these are a result of the standard random weight initialisations.

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

for i in range(3):
    ax = axs[i]
    plot_component_vector_field(vf, ax, comp = i, x_range=10, y_range=10)
    ax.set_title('Vector Field {}'.format(i+1))

plt.show()

# save the figure
# fig.savefig('./figures/synthetic-paths/initial_vf.png')

# %% [markdown]
# By looking at the summed rows of the corresponding cochain data matrix, we get a mapping from each path to $\mathbb{R}^3$, where 3 is the number of feature vector fields and the coordinates corespond to integration along each vector field. As we can see, the initialised vector fields do not generate representations that separate the paths into the three classes.

# %%
def path_to_chain(p):
    """  
    A function for turning a path into a chain

    Parameters
    ----------
    p : numpy array
        A path in R^n, represented as a numpy array of shape (p,n), where p is the number of points in the path

    Returns
    -------
    chain : numpy array
        A chain in R^n, represented as a numpy array of shape (p-1,2,n), where p is the number of points in the path.
        The middle index corresponds to start and endpoints of the edges in the chain.
    """

    r = len(p) - 1

    n = p[0].shape[0]
    
    
    chain = torch.zeros((r,2,n))

    chain[:,1,:] = torch.tensor(p[1:,:])
    chain[:,0,:] = torch.tensor(p[0:-1,:])

    return chain

# %%
# make a 3d scatter plot of vf evaluated on the set of paths, colored by labels
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection='3d')

correct = 0

for i in range(len(paths)):
        
        p = paths[i]
        l = labels[i]

        # convert the path into an embedded edge chain
        p = path_to_chain(p)

        # calculate the integration matrix of the embedded chain against the neural vector fields
        X = generate_integration_matrix(vf, p, d = 5)
        
        # column sum read-out layer
        X = torch.sum(X, dim = 0)

        # prediction
        lb = torch.argmax(l)
        pred = torch.argmax(torch.nn.functional.softmax(X))

        # calculate accuracy
        if pred == lb:
            correct +=1
        
        # add to plot
        if lb == 0:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'green', alpha = 0.5)
        elif lb == 1:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'red', alpha = 0.5)
        elif lb == 2:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'blue', alpha = 0.5)


print('Accuracy: {}'.format(correct/len(paths)))


# add a title to the figure
fig.suptitle('Initial path embeddedings before training colored by label')

# save the figure
# fig.savefig('./figures/synthetic-paths/initial_embeddings.png')

plt.show()
# Out:
# /tmp/ipykernel_362063/27644302.py:24: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = torch.argmax(torch.nn.functional.softmax(X))
# Accuracy: 0.0

# %% [markdown]
# ### Training and Gradient Descent
#
# Now we begin the training phase. We use stand SGD with a learning rate of 0.01 and a momentum of 0.9. We train for 50 epoches and employ a Cross-Entropy loss.

# %%
import torch.optim as optim

# create your optimizer
optimizer = optim.Adam(vf.parameters(), lr=1e-10)

criterion = nn.CrossEntropyLoss()

# %%
epochs = 10
losses = []
print(losses)
for epoch in range(epochs):  # loop over the dataset multiple times
    for path in paths:
        p = path_to_chain(path)
        X = generate_integration_matrix(vf, p, d = 15)
        print(X.shape)
        X = torch.sum(X, dim = 0)
        loss = -X[0]  # Assuming you want to minimize the negative of the first component of X
        print(loss)
        optimizer.zero_grad()  # Reset gradients
        loss.backward()
        optimizer.step()
        
        losses.append(loss.item())
# plot the loss
print(losses)
plt.plot(losses)
plt.title('Loss over training')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
# Out:
# []
# torch.Size([49, 3])
# tensor(0.1518, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0155, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0891, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0314, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0155, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0824, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0911, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.1022, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0936, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0242, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.1139, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0878, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.1105, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0470, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.1357, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0199, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0474, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0104, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0627, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0695, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0101, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0181, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0950, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.1009, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0138, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0208, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.1214, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0775, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0759, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0353, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0507, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0818, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.1074, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0635, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0551, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0343, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.1143, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0728, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.1074, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0380, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0317, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.1208, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0095, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0218, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0731, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0136, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0622, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0102, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.1083, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0607, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0481, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0515, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0262, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0279, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.0347, grad_fn=<NegBackward0>)
# torch.Size([49, 3])
# tensor(0.
.034307222813367844, 0.11430957168340683, 0.07279294729232788, 0.10735388100147247, 0.03796951472759247, 0.03172861039638519, 0.12079991400241852, 0.00951867550611496, 0.02181210182607174, 0.07309778779745102, 0.013614831492304802, 0.06224777549505234, 0.010208457708358765, 0.10831958800554276, 0.06067025661468506, 0.04810510203242302, 0.05145832523703575, 0.026212994009256363, 0.027948198840022087, 0.034693654626607895, 0.14749285578727722, 0.08015778660774231, 0.03808557242155075, 0.04904966801404953, 0.008585747331380844, 0.05323510989546776, 0.010974050499498844, 0.14024029672145844, 0.08250059187412262, 0.021814195439219475, 0.011217168532311916, 0.02338968589901924, 0.10354340076446533, 0.052545417100191116, 0.09672875702381134, 0.03629053384065628, 0.06379570066928864, 0.0831550732254982, 0.019239909946918488, 0.09747488051652908, 0.06693187355995178, 0.00838578213006258, 0.06957029551267624, 0.05111690238118172, 0.08472225069999695, 0.07101882249116898, 0.05424926429986954, 0.011700710281729698, 0.08141335099935532, 0.09553394466638565, 0.011127847246825695, 0.07170342653989792, 0.04505959525704384, 0.12335769 ...

# %%
fig, axs = plt.subplots(3, 1, figsize=(5, 15))

for i in range(3):
    ax = axs[i]
    plot_component_vector_field(vf, ax, comp = i, x_range=10, y_range=10)
    ax.set_title('Component {}'.format(i+1))

# add a title to the figure
fig.suptitle('Final feature vector fields')

plt.show()

# %%
epochs = 50

batch_size = 300

losses = torch.zeros((batch_size,epochs))

for j in range(epochs):

    # make a random choice of size batch_size
    idx = np.random.choice(len(paths), size=batch_size)

    batch_paths = [paths[i] for i in idx]
    batch_labels = labels[idx]

        
    for i in range(batch_size):

        p = batch_paths[i]
        l = batch_labels[i]

        # convert the path into an embedded edge chain
        p = path_to_chain(p)
        
        # calculate the integration matrix of the embedded chain against the neural vector fields
        X = generate_integration_matrix(vf, p, d = 5)

        # column sum read-out layer
        X = torch.sum(X, dim = 0)

        # prediction
        sm = torch.nn.functional.softmax(X)

        # calculate loss
        loss = criterion(sm,l.float())
        losses[i,j] = loss.detach()

        # backprop
        loss.backward()

        # for some reason it works better doing the backprop/gradient step after each path

        optimizer.step()

        optimizer.zero_grad()

    # clear print statement from previous iteration
    # clear_output(wait=True)
    
    print("Epoch = ", j, "Loss = ", torch.sum(losses[:,j])/batch_size)


fig, axs = plt.subplots(3, 1, figsize=(5, 15))

for i in range(3):
    ax = axs[i]
    plot_component_vector_field(vf, ax, comp = i, x_range=10, y_range=10)
    ax.set_title('Component {}'.format(i+1))

# add a title to the figure
fig.suptitle('Final feature vector fields')

plt.show()
# Out:
# /tmp/ipykernel_362063/128233923.py:31: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   sm = torch.nn.functional.softmax(X)
# Epoch =  0 Loss =  tensor(0.9773)
# Epoch =  1 Loss =  tensor(0.7999)
# Epoch =  2 Loss =  tensor(0.6956)
# Epoch =  3 Loss =  tensor(0.6472)
# Epoch =  4 Loss =  tensor(0.5967)
# Epoch =  5 Loss =  tensor(0.5780)
# Epoch =  6 Loss =  tensor(0.5676)
# Epoch =  7 Loss =  tensor(0.5648)
# Epoch =  8 Loss =  tensor(0.5613)
# Epoch =  9 Loss =  tensor(0.5590)
# Epoch =  10 Loss =  tensor(0.5573)
# Epoch =  11 Loss =  tensor(0.5557)
# Epoch =  12 Loss =  tensor(0.5552)
# Epoch =  13 Loss =  tensor(0.5548)
# Epoch =  14 Loss =  tensor(0.5544)
# Epoch =  15 Loss =  tensor(0.5540)
# Epoch =  16 Loss =  tensor(0.5537)
# Epoch =  17 Loss =  tensor(0.5535)
# Epoch =  18 Loss =  tensor(0.5535)
# Epoch =  19 Loss =  tensor(0.5533)
# Epoch =  20 Loss =  tensor(0.5530)
# Epoch =  21 Loss =  tensor(0.5530)
# Epoch =  22 Loss =  tensor(0.5529)
# Epoch =  23 Loss =  tensor(0.5528)
# Epoch =  24 Loss =  tensor(0.5526)
# Epoch =  25 Loss =  tensor(0.5525)
# Epoch =  26 Loss =  tensor(0.5526)
# Epoch =  27 Loss =  tensor(0.5525)
# Epoch =  28 Loss =  tensor(0.5524)
# Epoch =  29 Loss =  tensor(0.5525)
# Epoch =  30 Loss =  tensor(0.5523)
# Epoch =  31 Loss =  tensor(0.5523)
# Epoch =  32 Loss =  tensor(0.5523)
# Epoch =  33 Loss =  tensor(0.5522)
# Epoch =  34 Loss =  tensor(0.5522)
# Epoch =  35 Loss =  tensor(0.5522)
# Epoch =  36 Loss =  tensor(0.5521)
# Epoch =  37 Loss =  tensor(0.5521)
# Epoch =  38 Loss =  tensor(0.5521)
# Epoch =  39 Loss =  tensor(0.5521)
# Epoch =  40 Loss =  tensor(0.5521)
# Epoch =  41 Loss =  tensor(0.5520)
# Epoch =  42 Loss =  tensor(0.5520)
# Epoch =  43 Loss =  tensor(0.5520)
# Epoch =  44 Loss =  tensor(0.5519)
# Epoch =  45 Loss =  tensor(0.5520)
# Epoch =  46 Loss =  tensor(0.5520)
# Epoch =  47 Loss =  tensor(0.5519)
# Epoch =  48 Loss =  tensor(0.5519)
# Epoch =  49 Loss =  tensor(0.5519)

# %% [markdown]
# As we see below, the loss behaves very nicely with respect to the epochs.

# %%
# plot the loss
# L = torch.sum(losses,axis=0)/batch_size
plt.plot(losses.detach().numpy())

# add x and y labels
plt.xlabel('Epoch')
plt.ylabel('Average Loss')

# save the figure
# plt.savefig('./figures/synthetic-paths/training-loss.png')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 3
#       1 # plot the loss
#       2 # L = torch.sum(losses,axis=0)/batch_size
# ----> 3 plt.plot(losses.detach().numpy())
#       5 # add x and y labels
#       6 plt.xlabel('Epoch')
#
# AttributeError: 'list' object has no attribute 'detach'

# %%
# make a 3d scatter plot of vf evaluated on the set of paths, colored by labels
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection='3d')

# evaluate the accuracy of the classifier on the training data
correct = 0
total = 0

for i in range(len(paths)):
        
        p = paths[i]
        l = labels[i]
        
        p = path_to_chain(p)
        X = generate_integration_matrix(vf, p, d = 5)
        
        X = torch.sum(X, dim = 0)/path_length(p)

        lb = torch.argmax(l)

        pred = torch.argmax(torch.nn.functional.softmax(X))

        if pred == torch.argmax(l):
                correct += 1
        total += 1
        
        
        if lb == 0:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'green', alpha = 0.5)
        elif lb == 1:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'red', alpha = 0.5)
        elif lb == 2:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'blue', alpha = 0.5)


print('Accuracy of the network on the 300 training paths: %d %%' % (100 * correct / total))

# rotate the figure

ax.view_init(45, 45)


# save the figure
# fig.savefig('./figures/synthetic-paths/final-embeddings.png')

plt.show()
# Out:
# /tmp/ipykernel_362063/3451325322.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = torch.argmax(torch.nn.functional.softmax(X))
# Accuracy of the network on the 300 training paths: 100 %

# %%
fig, axs = plt.subplots(1, 3, figsize=(16, 5))

# plot the three component vector fields
for i in range(3):
    ax = axs[i]
    plot_component_vector_field(vf, ax, comp = i, x_range=4, y_range=4)
    ax.set_title('Component {}'.format(i+1))

# add example paths from each class
plot_path(paths[0], axs[0], color = 'green', head_width=0.2, head_length = 0.2, alpha = 0.6, linewidth = 2)

plot_path(paths[1], axs[1], color = 'red', head_width=0.2, head_length = 0.2, alpha = 0.6, linewidth = 2)

plot_path(paths[2], axs[2], color = 'blue', head_width=0.2, head_length = 0.2, alpha = 0.6, linewidth = 2)

# save the figure
# fig.savefig('./figures/synthetic-paths/final-vf.png')

plt.show()

# %% [markdown]
# ## 0-forms: Scalar Fields

# %% [markdown]
# Many authors have considered whether comparable results can be performed by networks that take only the point cloud of embedded vertices into account. To test whether the $1$-simplices are in fact necessary, we will take a $0$-form cochain representation network with as many parameters as the above as a comparison.
#
# To clarify, a $0$-form cochain neural network consists of learning $c$-features (for $c \in \mathbb{N}$) where each feature is a function from $\mathbb{R}^2 \to \mathbb{R}$. This can modelled as a simple MLP i.e. a function from $\mathbb{R}^2 \to \mathbb{R}^c$ with a finite number of parameters.

# %% [markdown]
# ### Initialisation
#
# We initiaise the function below, and note that this has slightly more paramters than our previous model.

# %%
c = 3 # number of features/columns in cochain data matrix

# intialise 3 neural scalar functions with 2 hidden layers
scalar = nn.Sequential(
    nn.Linear(2, 50),
    nn.ReLU(),
    nn.Linear(50, 32),
    nn.ReLU(),
    nn.Linear(32, c)
)

# print the total number of parameters in the model
print("Total Number of Parameters: ", sum(p.numel() for p in scalar.parameters()))
# Out:
# Total Number of Parameters:  1881

# %% [markdown]
# Like the previous example, we can plot individual $0$-form component features as scalar fields over $\mathbb{R}^2$, where $\mathbb{R}^2$ is the ambient embedding spaces of the nodes. This gives a helpful aid in interpreting the results of the network.

# %%
# a function to plot a heatmap of the scalar field
def plot_scalar_field_comp(scalar, ax, comp = 0, x_range = 5, y_range = 5, n = 100):
    x = np.linspace(-x_range, x_range, n)
    y = np.linspace(-y_range, y_range, n)
    X, Y = np.meshgrid(x, y)
    Z = np.zeros((n,n))
    for i in range(n):
        for j in range(n):
            Z[i,j] = scalar(torch.tensor([X[i,j],Y[i,j]]).float())[comp]
    ax.pcolormesh(X, Y, Z, cmap = 'viridis')

    # add a colorbar
    fig.colorbar(ax.pcolormesh(X, Y, Z, cmap = 'plasma'), ax=ax)

    # add a title labelling the component
    ax.set_title('Component {}'.format(comp))


fig, axs = plt.subplots(1, 3, figsize=(16, 5))

# plot the three component vector fields
for i in range(3):
    ax = axs[i]
    plot_scalar_field_comp(scalar, ax, comp = i, x_range=5, y_range=5)

# add a title to the figure
# fig.suptitle('Initial feature scalar fields')

# save the figure
fig.savefig('./figures/synthetic-paths/initial-scalar-fields.png')

plt.show()

# %% [markdown]
# Again, as in the previous example, specifiying 3 features means that we embed set of points corresponding to a path into $\mathbb{R}^3$. To demonstrate, we show the embedding of the three paths in the dataset below at the initialisation stage.

# %%
# make a 3d scatter plot of vf evaluated on the set of paths, colored by labels
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection='3d')

# evaluate the accuracy of the classifier on the training data
correct = 0
total = 0

for i in range(len(paths)):
        
        p = paths[i]
        l = labels[i]
        
        out = scalar(torch.tensor(p).float())
        X = torch.sum(out, dim = 0)

        lb = torch.argmax(l)

        pred = torch.argmax(torch.nn.functional.softmax(X))

        if pred == torch.argmax(l):
                correct += 1
        total += 1
        
        
        if lb == 0:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'green', alpha = 0.5)
        elif lb == 1:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'red', alpha = 0.5)
        elif lb == 2:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'blue', alpha = 0.5)


# add a title to the figure
# ax.set_title('Initial feature scalar field embedding')

# print accuracy
print('Accuracy of the network on the 300 training paths: ", %d %%' % (100 * correct / total))
# Out:
# /tmp/ipykernel_567274/153285778.py:20: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = torch.argmax(torch.nn.functional.softmax(X))
# Accuracy of the network on the 300 training paths: ", 33 %

# %% [markdown]
# ### Training
#
# To make the results comparable, we use the same loss, SGD and epoch parameters as before

# %%
import torch.optim as optim

# create your optimizer
scalar_optimizer = optim.SGD(scalar.parameters(), lr=1e-5)

scalar_criterion = nn.CrossEntropyLoss()

# %%
epochs = 50

batch_size = 300

losses = torch.zeros((batch_size,epochs))

for j in range(epochs):

    # make a random choice of size batch_size
    idx = np.random.choice(len(paths), size=batch_size, replace=False)

    #idx = np.arange(batch_size)
    batch_paths = [paths[i] for i in idx]
    batch_labels = labels[idx]

        
    for i in range(batch_size):

        p = batch_paths[i]
        l = batch_labels[i]

        out = scalar(torch.tensor(p).float())
        out = torch.sum(out, dim = 0)
        
        sm = torch.nn.functional.softmax(out)


        loss = scalar_criterion(sm,l.float())

        losses[i,j] = loss.detach()

        
        loss.backward()

        # for some reason it works better doing the backprop/gradient step after each path
        

        scalar_optimizer.step()

        scalar_optimizer.zero_grad()

    # clear print statement from previous iteration
    # clear_output(wait=True)
    
    print("Epoch = ", j, "Loss = ", torch.sum(losses[:,j])/batch_size, "Pred: ", sm)
# Out:
# /tmp/ipykernel_567274/637642944.py:25: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   sm = torch.nn.functional.softmax(out)
# Epoch =  0 Loss =  tensor(1.2181) Pred:  tensor([3.2716e-07, 7.9956e-08, 1.0000e+00], grad_fn=<SoftmaxBackward0>)
# Epoch =  1 Loss =  tensor(1.2181) Pred:  tensor([1.0580e-12, 1.3880e-06, 1.0000e+00], grad_fn=<SoftmaxBackward0>)
# Epoch =  2 Loss =  tensor(1.2181) Pred:  tensor([1.0110e-06, 5.7748e-06, 9.9999e-01], grad_fn=<SoftmaxBackward0>)
# Epoch =  3 Loss =  tensor(1.2181) Pred:  tensor([3.6113e-17, 4.5194e-10, 1.0000e+00], grad_fn=<SoftmaxBackward0>)
# Epoch =  4 Loss =  tensor(1.2181) Pred:  tensor([3.0979e-08, 7.2381e-10, 1.0000e+00], grad_fn=<SoftmaxBackward0>)
# Epoch =
 1.0000e+00], grad_fn=<SoftmaxBackward0>)
# Epoch =  43 Loss =  tensor(1.2181) Pred:  tensor([7.8229e-09, 3.4727e-10, 1.0000e+00], grad_fn=<SoftmaxBackward0>)
# Epoch =  44 Loss =  tensor(1.2181) Pred:  tensor([2.5247e-10, 3.6086e-08, 1.0000e+00], grad_fn=<SoftmaxBackward0>)
# Epoch =  45 Loss =  tensor(1.2181) Pred:  tensor([6.4630e-12, 1.6990e-05, 9.9998e-01], grad_fn=<SoftmaxBackward0>)
# Epoch =  46 Loss =  tensor(1.2181) Pred:  tensor([8.3781e-09, 6.3481e-08, 1.0000e+00], grad_fn=<SoftmaxBackward0>)
# Epoch =  47 Loss =  tensor(1.2181) Pred:  tensor([2.2393e-08, 3.3762e-07, 1.0000e+00], grad_fn=<SoftmaxBackward0>)
# Epoch =  48 Loss =  tensor(1.2181) Pred:  tensor([3.4671e-08, 6.6973e-07, 1.0000e+00], grad_fn=<SoftmaxBackward0>)
# Epoch =  49 Loss =  tensor(1.2181) Pred:  tensor([4.0565e-11, 1.9895e-12, 1.0000e+00], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# As we see below, the model learns, but fails to acheive the same level of accuracy as the $1$-form model. This suggests that the $1$-simplices are indeed necessary for the model to learn the vector field.

# %%
# plot the loss
fig, ax = plt.subplots()

ax.plot(np.arange(epochs), torch.sum(losses, axis = 0)/batch_size)

plt.show()

# %% [markdown]
# Since everything is in low dimension, we can interpret what our model has learned. We plot the three learned features below, and see that they do not separate the paths into the three classes as well as the $1$-form model.

# %%
# make a 3d scatter plot of vf evaluated on the set of paths, colored by labels
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection='3d')

# evaluate the accuracy of the classifier on the training data
correct = 0
total = 0

for i in range(len(paths)):
        
        p = paths[i]
        l = labels[i]
        
        out = scalar(torch.tensor(p).float())
        X = torch.sum(out, dim = 0)

        lb = torch.argmax(l)

        pred = torch.argmax(torch.nn.functional.softmax(X))

        if pred == torch.argmax(l):
                correct += 1
        total += 1
        
        
        if lb == 0:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'green', alpha = 0.5)
        elif lb == 1:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'red', alpha = 0.5)
        elif lb == 2:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'blue', alpha = 0.5)


# add a title to the figure
# ax.set_title('Final feature scalar field embedding')

# print accuracy
print('Accuracy of the network on the 300 training paths: ", %d %%' % (100 * correct / total))

# save the figure
fig.savefig('./figures/synthetic-paths/final-scalar-field-embedding.png')
# Out:
# /tmp/ipykernel_567274/627557330.py:20: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = torch.argmax(torch.nn.functional.softmax(X))
# Accuracy of the network on the 300 training paths: ", 33 %

# %% [markdown]
# Finally, below we plot the paths against the features. Learning a set of $0$-forms is akin to learning a set of densities that distinguish the points on along the path in the three classes. Since our paths have a lot of overlap, this is a difficult task. One can see the learned densities do roughly correspond to unique regions of the paths, but this is insufficient to distinguish paths reliably.
#
# In conclusions, the model does not perform as well as the $1$-form model with the same number of parameters and all else equal. Indeed, this shows that in this example the $1$-simplices seem to be helpful in classifying the paths.

# %%
fig, axs = plt.subplots(1, 3, figsize=(16, 4))

# plot the three component vector fields
for i in range(3):
    ax = axs[i]
    plot_scalar_field_comp(scalar, ax, comp = i, x_range=5, y_range=5)

# add a title to the figure
# fig.suptitle('Final feature scalar fields')

# add example paths from each class
for i in range(20):

    plot_path(paths[0+i], axs[0], color = 'green', alpha = 0.6, linewidth = 2)

    plot_path(paths[100+i], axs[1], color = 'red', alpha = 0.6, linewidth = 2)

    plot_path(paths[200+i], axs[2], color = 'blue', alpha = 0.6, linewidth = 2)

# save  the figure
fig.savefig('./figures/synthetic-paths/final-scalar-fields.png')

plt.show()
